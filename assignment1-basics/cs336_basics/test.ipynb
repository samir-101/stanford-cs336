# %%
chr(0)
# Out:
# '\x00'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
test_string = "hello world! From সামির"
encoded = test_string.encode('utf-8')
print(list(test_string.encode('utf-8')))
len(list(test_string.encode('utf-8')))
encoded.decode()
# Out:
# [104, 101, 108, 108, 111, 32, 119, 111, 114, 108, 100, 33, 32, 70, 114, 111, 109, 32, 224, 166, 184, 224, 166, 190, 224, 166, 174, 224, 166, 191, 224, 166, 176]
# 'hello world! From সামির'

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join(bytestring.decode("utf-8"))
decode_utf8_bytes_to_str_wrong("সামির".encode("utf-8"))
# Out:
# 'সামির'

# %%
import regex as re
with open('../sample.txt') as f:
    corpus = f.read()
# corpus = "সামির"
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
corpus = re.findall(PAT, corpus)
tokens = []
for word in corpus:
    encoded = list(word.encode())
    tokens.append(encoded)
print(tokens)
# Out:
# [[108, 111, 119], [32, 108, 111, 119], [32, 108, 111, 119], [32, 108, 111, 119], [32, 108, 111, 119], [10], [108, 111, 119, 101, 114], [32, 108, 111, 119, 101, 114], [32, 119, 105, 100, 101, 115, 116], [32, 119, 105, 100, 101, 115, 116], [32, 119, 105, 100, 101, 115, 116], [10], [110, 101, 119, 101, 115, 116], [32, 110, 101, 119, 101, 115, 116], [32, 110, 101, 119, 101, 115, 116], [32, 110, 101, 119, 101, 115, 116], [32, 110, 101, 119, 101, 115, 116], [32, 110, 101, 119, 101, 115, 116]]

# %%
# max(counts.items)
num_merges = 5
new_id = 256
merges = {}
for step in range(num_merges):
    counts = {}
    for entry in tokens:
        for pair in zip(entry, entry[1:]):
            counts[pair] = counts.get(pair,0)+1
    sorted_counts = {v: k for k, v in sorted(counts.items(), key=lambda item: item[1], reverse = True)}
    chr1, chr2 = sorted_counts.get(max(sorted_counts.keys()))
    merges[(chr1, chr2)] = new_id
    for entry in tokens:
        print(f"before: {entry}")
        for i, char in enumerate(entry):
            if (len(entry) > 2) & (i < len(entry)-1):
                if (entry[i], entry[i+1]) == (chr1, chr2):
                    entry[i] = new_id
                    # print(f"entry[i+1:] = {entry[i+1:]}, entry[i+2:] = {entry[i+2:]}")
                    entry[i+1:] = entry[i+2:]
                    # print("True")
        print(f"after: {entry}")
    new_id += 1
# Out:
# before: [108, 111, 119]
# after: [108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [10]
# after: [10]
# before: [108, 111, 119, 101, 114]
# after: [108, 111, 119, 101, 114]
# before: [32, 108, 111, 119, 101, 114]
# after: [32, 108, 111, 119, 101, 114]
# before: [32, 119, 105, 100, 101, 115, 116]
# after: [32, 119, 105, 100, 101, 256]
# before: [32, 119, 105, 100, 101, 115, 116]
# after: [32, 119, 105, 100, 101, 256]
# before: [32, 119, 105, 100, 101, 115, 116]
# after: [32, 119, 105, 100, 101, 256]
# before: [10]
# after: [10]
# before: [110, 101, 119, 101, 115, 116]
# after: [110, 101, 119, 101, 256]
# before: [32, 110, 101, 119, 101, 115, 116]
# after: [32, 110, 101, 119, 101, 256]
# before: [32, 110, 101, 119, 101, 115, 116]
# after: [32, 110, 101, 119, 101, 256]
# before: [32, 110, 101, 119, 101, 115, 116]
# after: [32, 110, 101, 119, 101, 256]
# before: [32, 110, 101, 119, 101, 115, 116]
# after: [32, 110, 101, 119, 101, 256]
# before: [32, 110, 101, 119, 101, 115, 116]
# after: [32, 110, 101, 119, 101, 256]
# before: [108, 111, 119]
# after: [108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [32, 108, 111, 119]
# after: [32, 108, 111, 119]
# before: [10]
# after: [10]
# before: [108, 111, 119, 101, 114]
# after: [108, 111, 119, 101, 114]
# before: [32, 108, 111, 119, 101, 114]
# after: [32, 108, 111, 119, 101, 114]
# before: [32, 119, 105, 100, 101, 256]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 101, 256]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 101, 256]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 101, 119, 101, 256]
# after: [110, 101, 119, 257]
# before: [32, 110, 101, 119, 101, 256]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 101, 256]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 101, 256]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 101, 256]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 101, 256]
# after: [32, 110, 101, 119, 257]
# before: [108, 111, 119]
# after: [108, 258]
# before: [32, 108, 111, 119]
# after: [32, 108, 258]
# before: [32, 108, 111, 119]
# after: [32, 108, 258]
# before: [32, 108, 111, 119]
# after: [32, 108, 258]
# before: [32, 108, 111, 119]
# after: [32, 108, 258]
# before: [10]
# after: [10]
# before: [108, 111, 119, 101, 114]
# after: [108, 258, 101, 114]
# before: [32, 108, 111, 119, 101, 114]
# after: [32, 108, 258, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 101, 119, 257]
# after: [110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [108, 258]
# after: [108, 258]
# before: [32, 108, 258]
# after: [32, 259]
# before: [32, 108, 258]
# after: [32, 259]
# before: [32, 108, 258]
# after: [32, 259]
# before: [32, 108, 258]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [108, 258, 101, 114]
# after: [259, 101, 114]
# before: [32, 108, 258, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 101, 119, 257]
# after: [110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 119, 257]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 101, 119, 257]
# after: [110, 101, 260]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 260]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 260]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 260]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 260]
# before: [32, 110, 101, 119, 257]
# after: [32, 110, 101, 260]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 101, 260]
# after: [110, 261]
# before: [32, 110, 101, 260]
# after: [32, 110, 261]
# before: [32, 110, 101, 260]
# after: [32, 110, 261]
# before: [32, 110, 101, 260]
# after: [32, 110, 261]
# before: [32, 110, 101, 260]
# after: [32, 110, 261]
# before: [32, 110, 101, 260]
# after: [32, 110, 261]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 110, 261]
# after: [32, 262]
# before: [32, 110, 261]
# after: [32, 262]
# before: [32, 110, 261]
# after: [32, 262]
# before: [32, 110, 261]
# after: [32, 262]
# before: [32, 110, 261]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [108, 258]
# after: [108, 258]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [32, 259]
# after: [32, 259]
# before: [10]
# after: [10]
# before: [259, 101, 114]
# after: [259, 101, 114]
# before: [32, 259, 101, 114]
# after: [32, 259, 101, 114]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [32, 119, 105, 100, 257]
# after: [32, 119, 105, 100, 257]
# before: [10]
# after: [10]
# before: [110, 261]
# after: [110, 261]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]
# before: [32, 262]
# after: [32, 262]

# %%
tokens
# Out:
# [[108, 258],
#  [32, 259],
#  [32, 259],
#  [32, 259],
#  [32, 259],
#  [10],
#  [259, 101, 114],
#  [32, 259, 101, 114],
#  [32, 119, 105, 100, 257],
#  [32, 119, 105, 100, 257],
#  [32, 119, 105, 100, 257],
#  [10],
#  [110, 261],
#  [32, 262],
#  [32, 262],
#  [32, 262],
#  [32, 262],
#  [32, 262]]

# %%
set([item for sublist in tokens for item in sublist])
# Out:
# {10,
#  32,
#  33,
#  34,
#  39,
#  44,
#  46,
#  58,
#  60,
#  62,
#  63,
#  65,
#  66,
#  67,
#  70,
#  72,
#  73,
#  76,
#  79,
#  83,
#  84,
#  87,
#  89,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  124,
#  128,
#  156,
#  157,
#  226,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272}

# %%
len(set([item for sublist in tokens for item in sublist]))
# Out:
# 69

# %%
merges
# Out:
# {(115, 116): 256,
#  (101, 256): 257,
#  (111, 119): 258,
#  (108, 258): 259,
#  (119, 257): 260,
#  (101, 260): 261,
#  (110, 261): 262,
#  (32, 262): 275}

# %%
hello[:4]
# Out:
# [12, 34, 423, 41]

# %%
len(hello[4:])
# Out:
# 1
